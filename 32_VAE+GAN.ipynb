# %% [markdown]
# <a href="https://colab.research.google.com/github/stepan-zykov/selfedu/blob/main/32_VAE%2BGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

from tensorflow.keras.datasets import mnist
from tensorflow import keras
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input, Lambda, BatchNormalization, Dropout
from tensorflow.keras.layers import Conv2D, LeakyReLU

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train[y_train==7]
y_train = y_train[y_train==7]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
BUFFER_SIZE = x_train.shape[0]
BATCH_SIZE = 100

# %%
length = BUFFER_SIZE // BATCH_SIZE * BATCH_SIZE

# %%
x_train = x_train[:length]
y_train = y_train[:length]
print(x_train.shape, y_train.shape)
# Out:
# (6200, 28, 28) (6200,)

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(x_train).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
# формирование сетей
hidden_dim = 2

def dropout_and_batch(x):
  return Dropout(0.3)(BatchNormalization()(x))

input_img = Input((28, 28, 1))
x = Flatten()(input_img)
x = Dense(256, activation='relu')(x)
x = dropout_and_batch(x)

z_mean = Dense(hidden_dim)(x)
z_log_var = Dense(hidden_dim)(x)

def noiser(args):
  global z_mean, z_log_var
  z_mean, z_log_var = args
  N = K.random_normal(shape=(BATCH_SIZE, hidden_dim), mean=0., stddev=1.0)
  return K.exp(z_log_var / 2) * N + z_mean

h = Lambda(noiser, output_shape=(hidden_dim,))([z_mean, z_log_var])

input_dec = Input(shape=(hidden_dim,))
d = Dense(256, activation='relu')(input_dec)
d = dropout_and_batch(d)
d = Dense(28*28, activation='sigmoid')(d)
decoded = Reshape((28, 28, 1))(d)

encoder = keras.Model(input_img, h, name='encoder')
decoder = keras.Model(input_dec, decoded, name='decoder')
generator = keras.Model(input_img, decoder(encoder(input_img)), name="generator")

# %%
# дискриминатор
discriminator = tf.keras.Sequential()
discriminator.add(Conv2D(64, (5, 5), strides=(2, 2), padding='same', input_shape=[28, 28, 1]))
discriminator.add(LeakyReLU())
discriminator.add(Dropout(0.3))

discriminator.add(Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
discriminator.add(LeakyReLU())
discriminator.add(Dropout(0.3))

discriminator.add(Flatten())
discriminator.add(Dense(1))

# %%
# потери
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def generator_loss(fake_output):
    loss = cross_entropy(tf.ones_like(fake_output), fake_output)
    kl_loss = -0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    return (loss + kl_loss * 0.1)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %%
# обучение
@tf.function
def train_step(images):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(images, training=True)

        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator=  gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_disscriminator = gen_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_opimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_opimizer.apply_gradients(zip(gradients_of_disscriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# %%
@tf.function
def train_step(images):
  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(images, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)

  gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
  gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

  return gen_loss, disc_loss


def train(dataset, epochs):
  history = []
  MAX_PRINT_LABEL = 10
  th = BUFFER_SIZE // (BATCH_SIZE*MAX_PRINT_LABEL)

  n_epoch = 1
  for epoch in range(epochs):
    print(f'{n_epoch}/{EPOCHS}: ', end='')

    start = time.time()
    n = 0

    gen_loss_epoch = 0
    for image_batch in dataset:
      gen_loss, disc_loss = train_step(image_batch)
      gen_loss_epoch += K.mean(gen_loss)
      if( n % th == 0): print('=', end='')
      n += 1

    history += [gen_loss_epoch/n]
    print(': '+str(history[-1]))
    print ('Время эпохи {} в {} секундах'.format(epoch + 1, time.time()-start))

    n_epoch += 1
  return history

# %%
# запуск процесса обучения
EPOCHS = 50

history = train(train_dataset, EPOCHS)


h = encoder.predict(x_test[:6000], batch_size=BATCH_SIZE)
plt.scatter(h[:, 0], h[:, 1])

plt.plot(history)
plt.grid(True)

# отображение результатов генерации
n = 2
total = 2*n+1

plt.figure(figsize=(total, total))

num = 1
for i in range(-n, n+1):
  for j in range(-n, n+1):
    ax = plt.subplot(total, total, num)
    num += 1
    img = decoder.predict(np.expand_dims([0.5*i/n, 0.5*j/n], axis=0))
    plt.imshow(img.squeeze(), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# Out:
# 1/50: ===========: tf.Tensor(2.5790975, shape=(), dtype=float32)
# Время эпохи 1 в 11.51388931274414 секундах
# 2/50: ===========: tf.Tensor(6.232629, shape=(), dtype=float32)
# Время эпохи 2 в 0.5267205238342285 секундах
# 3/50: ===========: tf.Tensor(11.326359, shape=(), dtype=float32)
# Время эпохи 3 в 0.5293104648590088 секундах
# 4/50: ===========: tf.Tensor(17.257198, shape=(), dtype=float32)
# Время эпохи 4 в 0.529653787612915 секундах
# 5/50: ===========: tf.Tensor(22.6144, shape=(), dtype=float32)
# Время эпохи 5 в 0.5371913909912109 секундах
# 6/50: ===========: tf.Tensor(24.329271, shape=(), dtype=float32)
# Время эпохи 6 в 0.6258201599121094 секундах
# 7/50: ===========: tf.Tensor(22.63667, shape=(), dtype=float32)
# Время эпохи 7 в 0.5425410270690918 секундах
# 8/50: ===========: tf.Tensor(19.901016, shape=(), dtype=float32)
# Время эпохи 8 в 0.5865299701690674 секундах
# 9/50: ===========: tf.Tensor(18.650429, shape=(), dtype=float32)
# Время эпохи 9 в 0.5346848964691162 секундах
# 10/50: ===========: tf.Tensor(19.534748, shape=(), dtype=float32)
# Время эпохи 10 в 0.5316922664642334 секундах
# 11/50: ===========: tf.Tensor(20.005274, shape=(), dtype=float32)
# Время эпохи 11 в 0.5367879867553711 секундах
# 12/50: ===========: tf.Tensor(20.469492, shape=(), dtype=float32)
# Время эпохи 12 в 0.5257077217102051 секундах
# 13/50: ===========: tf.Tensor(19.455591, shape=(), dtype=float32)
# Время эпохи 13 в 0.534489631652832 секундах
# 14/50: ===========: tf.Tensor(16.79607, shape=(), dtype=float32)
# Время эпохи 14 в 0.5259487628936768 секундах
# 15/50: ===========: tf.Tensor(14.054601, shape=(), dtype=float32)
# Время эпохи 15 в 0.5357906818389893 секундах
# 16/50: ===========: tf.Tensor(13.041947, shape=(), dtype=float32)
# Время эпохи 16 в 0.5265703201293945 секундах
# 17/50: ===========: tf.Tensor(12.435716, shape=(), dtype=float32)
# Время эпохи 17 в 0.531951904296875 секундах
# 18/50: ===========: tf.Tensor(11.7715225, shape=(), dtype=float32)
# Время эпохи 18 в 0.5371222496032715 секундах
# 19/50: ===========: tf.Tensor(11.469291, shape=(), dtype=float32)
# Время эпохи 19 в 0.5328800678253174 секундах
# 20/50: ===========: tf.Tensor(10.8645525, shape=(), dtype=float32)
# Время эпохи 20 в 0.5297305583953857 секундах
# 21/50: ===========: tf.Tensor(9.900241, shape=(), dtype=float32)
# Время эпохи 21 в 0.5357677936553955 секундах
# 22/50: ===========: tf.Tensor(9.338055, shape=(), dtype=float32)
# Время эпохи 22 в 0.5313019752502441 секундах
# 23/50: ===========: tf.Tensor(9.444776, shape=(), dtype=float32)
# Время эпохи 23 в 0.5351345539093018 секундах
# 24/50: ===========: tf.Tensor(8.130057, shape=(), dtype=float32)
# Время эпохи 24 в 0.5317800045013428 секундах
# 25/50: ===========: tf.Tensor(8.650193, shape=(), dtype=float32)
# Время эпохи 25 в 0.534771203994751 секундах
# 26/50: ===========: tf.Tensor(7.420134, shape=(), dtype=float32)
# Время эпохи 26 в 0.533811092376709 секундах
# 27/50: ===========: tf.Tensor(7.726664, shape=(), dtype=float32)
# Время эпохи 27 в 0.5412595272064209 секундах
# 28/50: ===========: tf.Tensor(7.0273905, shape=(), dtype=float32)
# Время эпохи 28 в 0.6225531101226807 секундах
# 29/50: ===========: tf.Tensor(6.502436, shape=(), dtype=float32)
# Время эпохи 29 в 0.5619020462036133 секундах
# 30/50: ===========: tf.Tensor(6.608523, shape=(), dtype=float32)
# Время эпохи 30 в 0.5672314167022705 секундах
# 31/50: ===========: tf.Tensor(6.548119, shape=(), dtype=float32)
# Время эпохи 31 в 0.5406343936920166 секундах
# 32/50: ===========: tf.Tensor(6.126402, shape=(), dtype=float32)
# Время эпохи 32 в 0.544074535369873 секундах
# 33/50: ===========: tf.Tensor(6.219569, shape=(), dtype=float32)
# Время эпохи 33 в 0.5333504676818848 секундах
# 34/50: ===========: tf.Tensor(6.1447506, shape=(), dtype=float32)
# Время эпохи 34 в 0.5352365970611572 секундах
# 35/50: ===========: tf.Tensor(5.9107833, shape=(), dtype=float32)
# Время эпохи 35 в 0.5381782054901123 секундах
# 36/50: ===========: tf.Tensor(5.4628716, shape=(), dtype=float32)
# Время эпохи 36 в 0.5411930084228516 секундах
# 37/50: ===========: tf.Tensor(5.5632467, shape=(), dtype=float32)
# Время эпохи 37 в 0.5398373603820801 секундах
# 38/50: ===========: tf.Tensor(5.2666955, shape=(), dtype=float32)
# Время эпохи 38 в 0.5359768867492676 секундах
# 39/50: ===========: tf.Tensor(5.023994, shape=(), dtype=float32)
# Время эпохи 39 в 0.5410706996917725 секундах
# 40/50: ===========: tf.Tensor(5.126589, shape=(), dtype=float32)
# Время эпохи 40 в 0.5417594909667969 секундах
# 41/50: ===========: tf.Tensor(4.979646, shape=(), dtype=float32)
# Время эпохи 41 в 0.5405130386352539 секундах
# 42/50: ===========: tf.Tensor(4.605491, shape=(), dtype=float32)
# Время эпохи 42 в 0.5377662181854248 секундах
# 43/50: ===========: tf.Tensor(4.39877, shape=(), dtype=float32)
# Время эпохи 43 в 0.5381324291229248 секундах
# 44/50: ===========: tf.Tensor(4.2424464, shape=(), dtype=float32)
# Время эпохи 44 в 0.5400819778442383 секундах
# 45/50: ===========: tf.Tensor(4.222757, shape=(), dtype=float32)
# Время эпохи 45 в 0.5397651195526123 секундах
# 46/50: ===========: tf.Tensor(4.2139387, shape=(), dtype=float32)
# Время эпохи 46 в 0.5391252040863037 секундах
# 47/50: ===========: tf.Tensor(4.130414, shape=(), dtype=float32)
# Время эпохи 47 в 0.6228110790252686 секундах
# 48/50: ===========: tf.Tensor(3.745048, shape=(), dtype=float32)
# Время эпохи 48 в 0.5341212749481201 секундах
# 49/50: ===========: tf.Tensor(3.7555494, shape=(), dtype=float32)
# Время эпохи 49 в 0.5674450397491455 секундах
# 50/50: ===========: tf.Tensor(3.6329095, shape=(), dtype=float32)
# Время эпохи 50 в 0.5621621608734131 секундах
# 60/60 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
